# %% [markdown]
# <a href="https://www.kaggle.com/code/linabashammakh/arti308-lab2?scriptVersionId=296276854" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/post-covid-health-effects-dataset/post_covid_health_effects_dataset.csv

# %%
data = pd.read_csv('/kaggle/input/post-covid-health-effects-dataset/post_covid_health_effects_dataset.csv')

# %%
data.head()
# Out:
#    Age  Gender COVID_Severity Hospitalized  Days_to_Recovery  Fatigue_Level  \
# 0   56  Female           Mild           No               175              4
# 1   69  Female         Severe           No               128              4
# 2   46  Female           Mild          Yes               125              1
# 3   32  Female           Mild           No               120              1
# 4   60    Male       Moderate           No                16              3
#
#   Breathing_Issue Brain_Fog Loss_of_Taste_Smell Physical_Activity_Level  \
# 0              No        No                  No                     Low
# 1              No       Yes                  No                  Medium
# 2             Yes        No                  No                    High
# 3              No       Yes                  No                     Low
# 4              No        No                 Yes                  Medium
#
#    Mental_Health_Impact Long_COVID_Risk
# ...

# %%
data.tail()
# Out:
#      Age  Gender COVID_Severity Hospitalized  Days_to_Recovery  Fatigue_Level  \
# 495   65    Male           Mild           No                27              5
# 496   42  Female           Mild          Yes                63              5
# 497   57    Male           Mild          Yes               123              5
# 498   62    Male       Moderate           No                52              3
# 499   18    Male           Mild           No               148              5
#
#     Breathing_Issue Brain_Fog Loss_of_Taste_Smell Physical_Activity_Level  \
# 495             Yes        No                  No                     Low
# 496             Yes        No                 Yes                  Medium
# 497             Yes       Yes                 Yes                  Medium
# 498             Yes        No                 Yes                    High
# 499              No        No                 Yes                  Medium
#
#      Mental_Health_Impact Long_COVID_Risk
# ...

# %%
print('columns: ', data.columns)
# Out:
# columns:  Index(['Age', 'Gender', 'COVID_Severity', 'Hospitalized', 'Days_to_Recovery',
#        'Fatigue_Level', 'Breathing_Issue', 'Brain_Fog', 'Loss_of_Taste_Smell',
#        'Physical_Activity_Level', 'Mental_Health_Impact', 'Long_COVID_Risk'],
#       dtype='object')

# %%
print('rows and columns: ', data.shape)
# Out:
# rows and columns:  (500, 12)
