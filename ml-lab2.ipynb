# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/smartphone-battery-features/smartphone_battery_features.csv

# %%
data = pd.read_csv('/kaggle/input/smartphone-battery-features/smartphone_battery_features.csv')

# %%
data.head()
# Out:
#                               Device_ID  device_age_months  \
# 0  207dd94c-0430-43aa-b388-4893447e628e                 38
# 1  3f4d1d33-ba89-4814-a168-7b4cc75be26b                 28
# 2  b4adca05-564f-4b70-ab69-e8d66e656463                 14
# 3  4147e039-31b7-480a-bbc9-03cd0f66e9f1                 42
# 4  3f9b0fb7-73c2-4ab7-8e30-7b492097a3f5                  7
#
#    battery_capacity_mah  avg_screen_on_hours_per_day  \
# 0                  4500                          7.1
# 1                  3000                          6.8
# 2                  3000                          7.2
# 3                  3000                          5.5
# 4                  3000                          7.6
#
#    avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 0                          11.4                      34.8
# 1                          10.3                      35.4
# 2                          11.2                      29.4
# 3                           8.3                      32.8
# 4                          11.6                      38.7
#
#    fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 0                         90.8                                 7
# 1                         60.6                                 2
# 2                         29.3                                 4
# 3                         62.5                                 0
# 4                         85.4                                 6
#
#    gaming_hours_per_week  video_streaming_hours_per_week  \
# 0                    7.9                            14.0
# 1                    8.6                            11.0
# 2                    0.3                            10.3
# 3                    1.9                             4.9
# 4                    7.9                             9.3
#
#   background_app_usage_level signal_strength_avg  charging_habit_score  \
# 0                     Medium                Poor                     4
# 1                     Medium                Good                     7
# 2                     Medium                Good                     6
# 3                     Medium                Good                     8
# 4                       High                Good                     5
#
#    usage_intensity_score  thermal_stress_index
# 0                   10.0                  4.04
# 1                   10.0                  4.23
# 2                   10.0                  2.21
# 3                   10.0                  3.13
# 4                   10.0                  4.95

# %%
data.tail()
# Out:
#                                  Device_ID  device_age_months  \
# 4995  39b2fb64-26ad-4c44-9373-758ef3761740                  0
# 4996  708e9ce1-193f-415e-a1f1-8bbe6528cec1                 28
# 4997  6ce90202-2b2a-46e8-b313-936f2b5f32da                 21
# 4998  a289b415-2c3e-4cea-b987-6224987f4b1b                 15
# 4999  4edc1420-8e01-44a7-8806-6281ac8026a8                 40
#
#       battery_capacity_mah  avg_screen_on_hours_per_day  \
# 4995                  5000                          4.9
# 4996                  4000                          6.1
# 4997                  4500                          7.5
# 4998                  4500                          5.0
# 4999                  3000                          5.3
#
#       avg_charging_cycles_per_week  avg_battery_temp_celsius  \
# 4995                           7.3                      32.2
# 4996                          10.6                      33.9
# 4997                          12.1                      35.8
# 4998                           7.1                      29.5
# 4999                           8.0                      32.8
#
#       fast_charging_usage_percent  overnight_charging_freq_per_week  \
# 4995                         55.6                                 7
# 4996                         28.8                                 7
# 4997                         50.7                                 3
# 4998                         88.5                                 4
# 4999                         45.8                                 2
#
#       gaming_hours_per_week  video_streaming_hours_per_week  \
# 4995                    1.7                            13.4
# 4996                    4.9                             6.4
# 4997                    3.0                            16.6
# 4998                    0.7                             8.2
# 4999                   12.2                             4.0
#
#      background_app_usage_level signal_strength_avg  charging_habit_score  \
# 4995                     Medium            Moderate                     5
# 4996                        Low                Good                     5
# 4997                     Medium                Good                     6
# 4998                     Medium                Good                     7
# 4999                       High                Good                     7
#
#       usage_intensity_score  thermal_stress_index
# 4995                   10.0                  2.98
# 4996                   10.0                  3.60
# 4997                   10.0                  3.93
# 4998                   10.0                  2.28
# 4999                   10.0                  3.90

# %%
print('columns: ', data.columns)
# Out:
# columns:  Index(['Device_ID', 'device_age_months', 'battery_capacity_mah',
#        'avg_screen_on_hours_per_day', 'avg_charging_cycles_per_week',
#        'avg_battery_temp_celsius', 'fast_charging_usage_percent',
#        'overnight_charging_freq_per_week', 'gaming_hours_per_week',
#        'video_streaming_hours_per_week', 'background_app_usage_level',
#        'signal_strength_avg', 'charging_habit_score', 'usage_intensity_score',
#        'thermal_stress_index'],
#       dtype='object')

# %%
print('number of rows and columns: ', data.shape)
# Out:
# number of rows and columns:  (5000, 15)

# %%
print('data types: ', data.dtypes)
# Out:
# data types:  Device_ID                            object
# device_age_months                     int64
# battery_capacity_mah                  int64
# avg_screen_on_hours_per_day         float64
# avg_charging_cycles_per_week        float64
# avg_battery_temp_celsius            float64
# fast_charging_usage_percent         float64
# overnight_charging_freq_per_week      int64
# gaming_hours_per_week               float64
# video_streaming_hours_per_week      float64
# background_app_usage_level           object
# signal_strength_avg                  object
# charging_habit_score                  int64
# usage_intensity_score               float64
# thermal_stress_index                float64
# dtype: object
